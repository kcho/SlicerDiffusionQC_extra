# %% [markdown]
# # Diffusion QC summary
#
# ## Summarizing `Slicer DiffusionQC` outputs
#
# Friday, March 20, 2020
#
# Kcho

# %% [markdown]
# > import libraries

# %%
import sys
import numpy as np
sys.path.append('/data/pnl/kcho/PNLBWH/devel/SlicerDiffusionQC_extra')
from slicer_diffusion_qc_extra.sdqe import QcDataDir, QcStudyDir

# %%
study_qc_dir = '/data/pnl/kcho/tokyo_u/DiffusionQC'
raw_data_dir = '/data/pnl/kcho/tokyo_u/sourcedata'

qcStudyDir = QcStudyDir(study_qc_dir)

# get_failure_info function may have to be changed for you own projects
qcStudyDir.get_failure_info(raw_data_dir)

# %%
qcStudyDir.plot_KL_divergence_for_all()

# %%
qcStudyDir.plot_qc_confidence_for_all()

# %%
qcStudyDir.plot_failed_volume_count_for_all()

# %%
qcStudyDir.df.index = np.arange(len(qcStudyDir.df.index))
qcStudyDir.df
# Out:
#     registered shape files
# 0            1   NaN   NaN
# 1            1   NaN   NaN
# 2            1   NaN   NaN
# 3            1   NaN   NaN
# 4            1   NaN   NaN
# ..         ...   ...   ...
# 417          0   NaN
# 418          1   NaN   NaN
# 419          1   NaN   NaN
# 420          1   NaN   NaN
# 421          0   NaN
#
# [422 rows x 3 columns]

# %%
qcStudyDir.plot_KL_divergence_for_a_subject('subject_ID')

# %%
qcStudyDir.plot_KL_divergence_for_a_subject('subject_ID2')
